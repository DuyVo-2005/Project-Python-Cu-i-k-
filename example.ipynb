# %% [markdown]
# # IMPORT DATA

# %%
# modules we'll use
import pandas as pd
import numpy as np

# read in all our data
data = pd.read_csv("AppleStore.csv")

data.head()
# Out:
#    no.         id                                         track_name  \
# 0    1  281656475                                    PAC-MAN Premium
# 1    2  281796108                          Evernote - stay organized
# 2    3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3    4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4    5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  user_rating  user_rating_ver  \
# 0   100788224      USD   3.99             21292          4.0              4.5
# 1   158578688      USD   0.00            161065          4.0              3.5
# 2   100524032      USD   0.00            188583          3.5              4.5
# 3   128512000      USD   0.00            262241          4.0              4.5
# 4    92774400      USD   0.00            985920          4.5              5.0
#
#       ver cont_rating   prime_genre  sup_devices.num
# ...

# %% [markdown]
# # Check missing value

# %%
from DataCleaning import check_missing_value

check_missing_value(data)
# Out:
# no.                 0
# id                  0
# track_name          0
# size_bytes          0
# currency            0
# price               0
# rating_count_tot    0
# user_rating         0
# user_rating_ver     0
# ver                 0
# cont_rating         0
# prime_genre         0
# sup_devices.num     0
# dtype: int64

# %% [markdown]
# # Fill NA

# %%
from DataCleaning import fill_na_value

fill_na_value(data)
# Out:
# d:\study\semester1_senior\LT Python\Project-Python-Cuoi-ki\DataCleaning.py:12: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   result = data.fillna(method='bfill', axis=0).fillna(0)
#         no.          id                                         track_name  \
# 0         1   281656475                                    PAC-MAN Premium
# 1         2   281796108                          Evernote - stay organized
# 2         3   281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3         4   282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4         5   282935706                                              Bible
# ...     ...         ...                                                ...
# 7192  11081  1187617475                                              Kubik
# 7193  11082  1187682390                                  VR Roller-Coaster
# ...
